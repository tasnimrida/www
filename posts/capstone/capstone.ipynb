# %% [raw]
# ---
# title: "Examining the Influence of Socioeconomic Factors on Premature Death Rates Across Racial Groups"
# description: "A statistical investigation into county-level predictors of health disparities."
# image: plot1.png
# date: August 2024
# page-layout: full
#
# format:
#   html:
#     theme: cosmo
#     toc: false
#     page-layout: full
# ---

# %% [markdown]
# ```{html}
# <style>
# body {
#   background: #202020;
#   overflow-x: hidden;
#   color: #111;
#   font-family: "Source Sans Pro", Arial, sans-serif;
# }
#
# #quarto-header,
# #title-block-header {
#   display: none;
# }
#
# #quarto-content,
# #quarto-document-content,
# .page-columns,
# .content,
# main.content {
#   width: 100% !important;
#   max-width: 100% !important;
#   margin: 0 !important;
# }
#
# main.content {
#   padding: 0 !important;
# }
#
# .poster-page {
#   background: #d9d9d9;
#   width: min(900px, calc(100vw - 48px));
#   margin: 42px auto;
#   padding: 54px 34px 210px 34px;
#   min-height: 2200px;
#   box-sizing: border-box;
# }
#
# .project-title {
#   text-align: center;
#   max-width: 650px;
#   margin: 0 auto;
#   font-size: clamp(1.7rem, 3vw, 2.35rem);
#   line-height: 1.08;
#   font-weight: 500;
#   letter-spacing: -0.5px;
# }
#
# .project-description {
#   text-align: center;
#   max-width: 560px;
#   margin: 24px auto 8px auto;
#   font-size: 0.9rem;
#   line-height: 1.18;
# }
#
# .star-row {
#   text-align: center;
#   color: #d497ff;
#   font-size: 1.15rem;
#   letter-spacing: 8px;
#   margin: 8px 0;
# }
#
# .project-date {
#   text-align: center;
#   font-size: 0.86rem;
#   margin-bottom: 26px;
# }
#
# .button-row {
#   display: flex;
#   justify-content: center;
#   gap: 18px;
#   margin-bottom: 92px;
#   flex-wrap: wrap;
# }
#
# .project-link,
# .project-link:visited {
#   display: inline-flex;
#   align-items: center;
#   gap: 8px;
#   background: #b7aaa9;
#   color: #111 !important;
#   text-decoration: none !important;
#   font-size: 0.78rem;
#   padding: 8px 18px;
#   border-radius: 0;
#   line-height: 1;
#   font-family: "Source Sans Pro", Arial, sans-serif;
# }
#
# .project-link:hover {
#   color: #111 !important;
#   background: #a99d9c;
# }
#
# .project-link i {
#   font-size: 0.95rem;
#   line-height: 1;
# }
#
# .section-grid {
#   display: grid;
#   grid-template-columns: 1fr 1fr;
#   gap: 28px;
#   align-items: start;
#   margin-bottom: 48px;
# }
#
# .question-wrap {
#   position: relative;
#   padding-top: 12px;
# }
#
# .question {
#   font-size: clamp(1.35rem, 2.5vw, 1.9rem);
#   line-height: 1.08;
#   max-width: 360px;
#   margin: 0 auto 28px auto;
#   text-align: left;
#   position: relative;
#   z-index: 2;
# }
#
# .question::before {
#   content: "✦ ✦ ✦";
#   position: absolute;
#   left: -32px;
#   top: 54px;
#   color: #d497ff;
#   font-size: 2.1rem;
#   letter-spacing: 4px;
#   z-index: -1;
# }
#
# .question::after {
#   content: "✦ ✦ ✦";
#   position: absolute;
#   right: -8px;
#   bottom: -8px;
#   color: #d497ff;
#   font-size: 1.8rem;
#   letter-spacing: 4px;
#   z-index: -1;
# }
#
# .card-box {
#   background: white;
#   border-radius: 14px;
#   min-height: 180px;
#   padding: 46px 28px 28px 28px;
#   box-shadow: 6px 8px 8px rgba(0,0,0,0.25);
#   position: relative;
#   box-sizing: border-box;
# }
#
# .card-box.tall {
#   min-height: 370px;
# }
#
# .card-box.findings {
#   min-height: 500px;
# }
#
# .tag {
#   position: absolute;
#   top: -22px;
#   left: 24px;
#   background: #b7ff95;
#   color: #111;
#   border-radius: 999px;
#   min-width: 145px;
#   padding: 17px 22px;
#   text-align: center;
#   font-size: 0.72rem;
#   font-weight: 600;
#   line-height: 1;
#   white-space: nowrap;
# }
#
# .card-box p {
#   font-size: 0.94rem;
#   line-height: 1.45;
#   margin: 0 0 1rem 0;
# }
#
# .card-box ul {
#   margin: 0;
#   padding-left: 1.1rem;
# }
#
# .card-box li {
#   font-size: 0.9rem;
#   line-height: 1.42;
#   margin-bottom: 0.85rem;
# }
#
# .image-wrap {
#   background: white;
#   padding: 0;
#   border-radius: 0;
# }
#
# .image-wrap img,
# .poster-photo img {
#   width: 100%;
#   display: block;
#   border-radius: 0;
# }
#
# .map-image {
#   margin-top: 8px;
# }
#
# .scatter-image {
#   margin-top: 28px;
# }
#
# .model-image {
#   margin-top: 80px;
# }
#
# .finding-pill {
#   background: #dddddd;
#   color: white;
#   border-radius: 12px;
#   padding: 14px 16px;
#   margin-bottom: 22px;
#   font-size: 0.82rem;
#   line-height: 1.2;
#   text-align: center;
# }
#
# .footer-grid {
#   display: grid;
#   grid-template-columns: 1.2fr 0.8fr;
#   gap: 28px;
#   align-items: center;
#   margin-top: 78px;
#   padding: 0 22px;
# }
#
# .note-card {
#   background: white;
#   border-radius: 12px;
#   padding: 18px 20px;
#   font-size: 0.84rem;
#   line-height: 1.22;
#   text-align: center;
# }
#
# @media (max-width: 760px) {
#   .poster-page {
#     width: calc(100vw - 24px);
#     margin: 18px auto;
#     padding: 36px 18px 90px 18px;
#     min-height: auto;
#   }
#
#   .button-row {
#     gap: 12px;
#     margin-bottom: 56px;
#   }
#
#   .section-grid,
#   .footer-grid {
#     grid-template-columns: 1fr;
#   }
#
#   .question {
#     max-width: 100%;
#     text-align: center;
#   }
#
#   .question::before,
#   .question::after {
#     display: none;
#   }
#
#   .model-image {
#     margin-top: 20px;
#   }
#
#   .card-box,
#   .card-box.tall,
#   .card-box.findings {
#     min-height: auto;
#   }
# }
# </style>
#
# <div class="poster-page">
#
# <div class="project-title">
# Examining the Influence of Socioeconomic Factors on Premature Death Rates Across Racial Groups
# </div>
#
# <div class="project-description">
# A statistical investigation into county-level predictors of health disparities, utilizing Gradient Boosted Trees and Linear Regression to identify key social determinants of health.
# </div>
#
# <div class="star-row">✦ ✦</div>
#
# <div class="project-date">
# August 2024
# </div>
#
# <div class="button-row">
# <a class="project-link" href="https://www.stat.cmu.edu/cmsac/sure/2024/showcase/premature_deaths/slides.pdf" target="_blank" rel="noopener noreferrer">
# <i class="bi bi-laptop"></i><span>Slides</span>
# </a>
#
# <a class="project-link" href="https://www.stat.cmu.edu/cmsac/sure/2024/showcase/premature_deaths/poster.pdf" target="_blank" rel="noopener noreferrer">
# <i class="bi bi-file-earmark-pdf"></i><span>Poster</span>
# </a>
#
# <a class="project-link" href="https://www.stat.cmu.edu/cmsac/sure/2024/showcase/premature_deaths/report.html" target="_blank" rel="noopener noreferrer">
# <i class="bi bi-pencil"></i><span>Report</span>
# </a>
# </div>
#
# <div class="section-grid">
#
# <div class="question-wrap">
#
# <div class="question">
# How do social determinants of health shape premature death rates across racial groups in the United States?
# </div>
#
# <div class="card-box">
# <div class="tag">RESEARCH OVERVIEW</div>
#
# <p>
# This project examines how socioeconomic factors influence premature death rates across U.S. counties and racial groups. Leveraging data from the County Health Rankings data set, the research quantifies the influence of systemic factors on premature mortality rates at the county level.
# </p>
# </div>
#
# </div>
#
# <div class="image-wrap map-image">
# <img src="plot1.png" alt="plot 1">
# </div>
#
# </div>
#
# <div class="section-grid">
#
# <div class="image-wrap scatter-image">
# <img src="plot2.png" alt="plot 2">
# </div>
#
# <div class="card-box tall">
# <div class="tag">METHODOLOGY</div>
#
# <p>
# The analytical framework employed statistical modeling in R to evaluate relationships between mortality and various Social Determinants of Health (SDOH). Based on exploratory data analysis, two distinct modeling approaches were compared:
# </p>
#
# <ul>
# <li>Multiple Linear Regression: Utilized to establish baseline correlations and effect sizes.</li>
# <li>Gradient Boosted Trees (XGBoost): Leveraged to capture non-linear relationships and high-dimensional interactions between variables.</li>
# </ul>
# </div>
#
# </div>
#
# <div class="section-grid">
#
# <div class="card-box findings">
# <div class="tag">KEY FINDINGS</div>
#
# <div class="finding-pill">
# Socioeconomic Impact: The analysis confirmed that increases in income inequality and unemployment are associated with increases in years of premature death. Conversely, as high school completion percentages increase, premature deaths decrease.
# </div>
#
# <div class="finding-pill">
# Variable Importance &amp; Model Divergence: Findings revealed a contrast between the two approaches. The multiple linear regression identified AIAN population percentage as the most important variable, likely due to the model's sensitivity to the small population percentages of this group across the U.S. In contrast, the gradient boosted tree—which proved more reliable with a lower RMSE—identified high school completion as the most significant predictor.
# </div>
# </div>
#
# <div class="image-wrap model-image">
# <img src="plot3.png" alt="plot 3">
# </div>
#
# </div>
#
# <div class="footer-grid">
#
# <div class="poster-photo">
# <img src="plot5.png" alt="poster photo">
# </div>
#
# <div class="note-card">
# This research was conducted as part of the Carnegie Mellon Summer Undergraduate Research Experience (SURE) program in partnership with UnitedHealth Group.
# </div>
#
# </div>
#
# </div>
# ```
